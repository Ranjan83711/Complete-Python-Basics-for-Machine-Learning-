# %% [markdown]
# # **Input**

# %%
q=100  #hard coded
q
# Out:
# 100

# %%
input()
# Out:
#  100
# '100'

# %%
input()
input()
input()
# Out:
#  20
#  abc
#  87
# '87'

# %%
n1=input('enter the no. :')
n2=input('enter the name :')
# Out:
# enter the no. : 100
# enter the name : abc

# %%
n1,n2
# Out:
# ('100', 'abc')

# %%
n1=input('enter the n1:')
n2=input('enter the n2:')
n1+n2
# Out:
# enter the n1: 100
# enter the n2: 200
# '100200'

# %%
n1=input('enter the n1:')
n2=input('enter the n2:')
int(n1)+int(n2)
# Out:
# enter the n1: 100
# enter the n2: 200
# 300

# %%
n1=int(input('enter the n1:'))
n2=int(input('enter the n2:'))
n1+n2
# Out:
# enter the n1: 100
# enter the n2: 200
# 300

# %%
n1=(input('enter the n1:'))
n2=(input('enter the n2:'))
int(n1+n2)
# Out:
# enter the n1: 12
# enter the n2: 15
# 1215

# %% [markdown]
# # EVAL()
#
# **To dynamically evaluate mathematical expressions stored as strings.**

# %%
eval('100')
# Out:
# 100

# %%
eval('200.5')
# Out:
# 200.5

# %%
n1=eval(input('enter the no.'))
n2=eval(input('enter the no.'))
# Out:
# enter the no. 10
# enter the no. 20

# %%
int('100')
# Out:
# 100

# %%
int('100.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int('100.5')
#
# ValueError: invalid literal for int() with base 10: '100.5'

# %%
float('100.5')
# Out:
# 100.5

# %%
n1=10
n2=20
n3=30
avg=(n1+n2+n3)/3
avg1=round(avg)
print(f"the average of {n1},{n2} and {n3} is : {avg}")
# Out:
# the average of 10,20 and 30 is : 20.0

# %%
n1=eval(input('enter the no.'))
n2=eval(input('enter the no.'))
n3=eval(input('enter the no.'))
avg=(n1+n2+n3)/3
avg1=round(avg,2)
print(f"the average of {n1},{n2} and {n3} is : {avg}")
# Out:
# enter the no. 15
# enter the no. 18
# enter the no. 17
# the average of 15,18 and 17 is : 16.666666666666668
