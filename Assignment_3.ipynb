# %%
import random

# %%
random.randint(1,10)
# Out:
# 1

# %%
random.choice(['apple','banana','orange','guava'])
# Out:
# 'orange'

# %%
random.sample(['apple','banana','orange','guava'],2)
# Out:
# ['apple', 'banana']

# %%
random.seed(10)

# %%
random.randint(1,20)
# Out:
# 19

# %%
import math

# %%
math.sqrt(64)
# Out:
# 8.0

# %%
math.pow(3,2)
# Out:
# 9.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
import time

# %%
time.sleep(2)

# %%
time.time()
# Out:
# 1758258157.8572667

# %%
import keyword

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Hp\\Documents\\NareshIT\\Python Session'

# %%
os.makedirs('assignment1')
