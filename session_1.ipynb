# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
import time
time.sleep(10)

# %% [markdown]
# - we develope the project
#
# - we need to create a document for client
#
# - jupyter notebook give the flexibilty
#
# - we can write the explations of each code line
#
# - we can insert diagrams
#
# - we can insert formulae
#
# - we can write bullet points
#
# - we can create a tables

# %% [markdown]
# # python

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1200px; height: 246px; margin: 0px; width: 246px;" alt="Python (programming language) - Wikipedia" jsname="kn3ccd">

# %%
num=100
num
# Out:
# 100

# %%
num=57
print(num)
# Out:
# 57
