# %% [markdown]
# # Variables

# %% [markdown]
# - Variable is  used to store the value in a memory
# - the value can be changes

# %%
num= 100
#100 is stored in variable num

# %%
num
# Out:
# 100

# %%
Ranjan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 Ranjan
#
# NameError: name 'Ranjan' is not defined

# %%
# Here Variable 'Ranjan' is not defined

# %%
n1=10
n2=20
n3=40
n=n1+n2+n3+n4
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 n2=20
#       3 n3=40
# ----> 4 n=n1+n2+n3+n4
#       5 n
#
# NameError: name 'n4' is not defined

# %%
# Here Variable 'n4' is not defined

# %%
n1=10
n2=20
n3=40
n=n1+n2+n3+n4
n4=30
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       2 n2=20
#       3 n3=40
# ----> 4 n=n1+n2+n3+n4
#       5 n4=30
#       6 n
#
# NameError: name 'n4' is not defined

# %%
# In pyhton code executes line by line, here n4 is defined after the n so error will coem as n4 is not defined before the 'n'

# %%
n1=100
n1,n2=100,200
n1,n2=300
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 n1=100
#       2 n1,n2=100,200
# ----> 3 n1,n2=300
#
# TypeError: cannot unpack non-iterable int object

# %%
n1,n2=100,200

# %%
print(n1)
print(n2)
# Out:
# 100
# 200

# %%
n1,n2=300
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 n1,n2=300
#
# TypeError: cannot unpack non-iterable int object

# %%
Number=100

# %%
Number
# Out:
# 100

# %% [markdown]
# - Variables are case sensitive
#
# - Varibles can be uppercase also can be lowercase
#
# - Variables shouled not start with numbers
#
# - Variables should not include special characters
#
# - Variables can contains underscore(_)
#
# - Variables cannot be a math inbuilt function
#
# - Variables cannot be a reserved keywords

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Hp'
