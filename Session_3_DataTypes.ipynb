# %%
# this notebook i opened from th home tab

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Hp\\Documents\\NareshIT\\Python Session'

# %% [markdown]
# # Inbuilt Function

# %%
#functions always with ()
#print()
#max()
#min()
#type()

# %% [markdown]
# - when ever you miss the brackets for function it will give indiaction
#   - it will display as **function**
#   - it will display as **bound method**

# %%
l=[1,2,3,4,5]
print(type(l))
print(max(l))
print(min(l))
print(len(l))
# Out:
# <class 'list'>
# 5
# 1
# 5

# %% [markdown]
# # DataTypes

# %% [markdown]
# - int
# - float
# - bool
# - str
# - complex
# - range
# - list
# - tuple
# - dict
# - set
# - frozenset
# - bytearray
# - bytes
# - memoryview

# %% [markdown]
# ## $Integer$

# %%
num=100
print(type(num))
print(num)
# Out:
# <class 'int'>
# 100

# %% [markdown]
# ## $Float$

# %%
money=13.32
type(money)
# Out:
# float

# %%
print(1e1)  # 1*10
print(1e2)   # 1*100
print(1e3)   # 1*1000
# Out:
# 10.0
# 100.0
# 1000.0

# %%
print(1e+1)
print(1e+2)
# Out:
# 10.0
# 100.0

# %%
print(1e-1)
print(1e-2)
# Out:
# 0.1
# 0.01

# %% [markdown]
# ## $Strings$

# %%
name='Python'
print(type(name))
# Out:
# <class 'str'>

# %%
city="Hyderabad"
city
# Out:
# 'Hyderabad'

# %%
# name : single equotes
# city : double quotes
name , city  # by default single quotes only
# Out:
# ('Python', 'Hyderabad')

# %%
print(name,city)  # whenever we print the answers without quotes
# Out:
# Python Hyderabad

# %% [markdown]
# ## $triple Quotes$
# - triple quotes are used to write multiple lines
# - if i want to write an info, i can use **markdown** in jupyter
# - but in vs code there is no markdown
# - then we can use triple quotes to convey the info
# - this procedure is known as **doc string**
# - in prompt engineering also we use multiples quotes

# %%
""" I am learning Python data types
which is very easy"""
# Out:
# ' I am learning Python data types\nwhich is very easy'

# %%
'i like 'python''
# Out:
#   Cell In[4], line 1
#     'i like 'python''
#              ^
# SyntaxError: invalid syntax

# %%
"i like "python""
# Out:
#   Cell In[6], line 1
#     "i like "python""
#              ^
# SyntaxError: invalid syntax

# %%
srt1='I like "Python"'
print(srt1)
# Out:
# I like "Python"

# %%
# 'python'
# 'python
# "python
# "python'
# Out:
#   Cell In[12], line 1
#     'python
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"python'
# Out:
#   Cell In[14], line 1
#     "python'
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# # *Boolean*

# %% [markdown]
# - True indicates 1, ON
#
# - False indicates 0, OFF

# %%
value=True
type(value)
# Out:
# bool

# %%
value=False
type(value)
# Out:
# bool

# %%
true=True
false='False'
true=100
false=true
print(true)
print(false)
# True=10 # error
# Out:
# 100
# 100
