# %%
# wap ask the user take two number print subtraction multiplication and division

num1=eval(input('enter the no.'))
num2=eval(input('enter the no.'))
sub=num1-num2
mul=num1*num2
div=num1/num2
print(f"subraction is : {sub}")
print(f"multiplication is : {mul}")
print(f"division is : {div}")
# Out:
# enter the no. 15
# enter the no. 16
# subraction is : -1
# multiplication is : 240
# division is : 0.9375

# %%
# wap ask the user take the radius find the area of circle

r=eval(input('enter the radius'))
pi=3.14
area=pi*r*r
print(f"area is : {area}")
# Out:
# enter the radius 10
# area is : 314.0

# %%
# wap ask the user take height and breadth find the area of traingle

h=eval(input('enter the height'))
b=eval(input('enter the breadth'))
area=0.5*h*b
print(f"area of triangle is : {area}")
# Out:
# enter the height 10
# enter the breadth 5
# area of triangle is : 25.0

# %%
# wap ask the user take 3 numbers find the average

a=eval(input('enter the first no.'))
b=eval(input('enter the second no.'))
c=eval(input('enter the third no.'))
avg=(a+b+c)/3
print(f"average of {a}, {b} and {c} is : {avg}")
# Out:
# enter the first no. 15
# enter the second no. 19
# enter the third no. 17
# average of 15, 19 and 17 is : 17.0

# %%
# wap ask the user take the bill amount and tip amount calculate total bill

bill=eval(input('enter the bill'))
tip=eval(input('enter the tip'))
total_amount=bill+tip
print(f"total bill is : {total_amount}")
# Out:
# enter the bill 1000
# enter the tip 100
# total bill is : 1100

# %%
# wap ask the user take the salary, percetage of tax calculate tax amount

salary=eval(input('enter the salary'))
tax_percent=eval(input('enter the tax percent'))
tax_amount=salary*tax_percent/100
print(f"tax amount is : {tax_amount}")
# Out:
# enter the salary 15000
# enter the tax percent 10
# tax amount is : 1500.0

# %%
# wap ask the user take the value in dollar convert into rupees

rate=80
Dollar=eval(input('enter the amount in dollar'))
Indian_rupees=Dollar*rate
print(f"{Dollar} dollar is {Indian_rupees} rupees")
# Out:
# enter the amount in dollar 10
# 10 dollar is 800 rupees

# %%
# wap ask the use take weight in kgs convert into pounds

weight=eval(input("enter the weight in kg"))
weight_in_pound=2.2*weight
weight_in_pound1=round(weight_in_pound,2)
print(f"total weight in pound is {weight_in_pound1}")
# Out:
# enter the weight in kg 15
# total weight in pound is 33.0
