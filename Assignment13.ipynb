# %%
# 'isalnum',
# 'isalpha',
# 'isascii',
# 'isdecimal',
# 'isdigit',
# 'isidentifier',
# 'islower',
# 'isnumeric',
# 'isprintable',
# 'isspace',
# 'istitle',
# 'isupper',

# %%
str1='abc345'
str1.isalnum()
# Out:
# True

# %%
str1='abc'
str1.isalpha()
# Out:
# True

# %%
str1='abcdef123@.12'
str1.isascii()
# Out:
# True

# %%
str1='3.1'
str1.isdecimal()
# Out:
# False

# %%
str1='123'
str1.isdigit()
# Out:
# False

# %%
str1='Print'
str1.isidentifier()
# Out:
# True

# %%
str1.islower()
# Out:
# False

# %%
str1.isupper()
# Out:
# False

# %%
str1.isnumeric()
# Out:
# False

# %%
str1.isprintable()
# Out:
# True

# %%
str1=' '
str1.isspace()
# Out:
# True

# %%
str1='Hello'
str1.istitle()
# Out:
# True

# %%
str1.isupper()
# Out:
# False
